# %%
# load libraries
# %matplotlib inline
import fiona
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import time
import os
from mapclassify import Quantiles, EqualInterval
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Connect to excel, just read rows and columns that are neccesary
df = pd.read_excel ('2_cuadro_8.5_3.xlsx', usecolsstr = 'A:O', nrows = 28)

# %%
# Visualize tabular data
df
# Out:
#                        Departamento    2008    2009    2010      2011  \
# 0                             Total  151560  160848  181866  240438.0
# 1                          Amazonas    1247     860     640    3309.0
# 2                            Áncash    5381    5744    6626    6325.0
# 3                          Apurímac    1191    1267    1389    1855.0
# 4                          Arequipa   10469   11110   10935   12762.0
# 5                          Ayacucho    2221    2124    1856    3299.0
# 6                         Cajamarca    3137    2665    3851    3775.0
# 7           Prov. Const. del Callao    8219    8935   10010   12749.0
# 8                             Cusco    4767    5742    6445    7145.0
# 9                      Huancavelica     110     273     600     879.0
# 10                          Huánuco    1048    1602    1514    1931.0
# 11                              Ica    3239    3895    4716    6308.0
# 12                            Junín    3614    2777    4672    7123.0
# 13                      La Libertad    7440    8061   11570    9221.0
# 14                       Lambayeque   10525   14292   11746   10300.0
# 15  Lima Metropolitana 1/ y Lima 2/     NaN     NaN     NaN       NaN
# 16            Lima Metropolitana 1/       …       …       …  115608.0
# 17                          Lima 2/       …       …       …   10886.0
# 18                           Loreto    3878    4332    5053    2711.0
# 19                    Madre de Dios     648     297     496     814.0
# 20                         Moquegua    1249    1602    1739    2231.0
# 21                            Pasco     206     244     259     999.0
# 22                            Piura    4759    4871    6475    7328.0
# 23                             Puno    1543    1499    1556    1756.0
# 24                       San Martín    2803    1642    2421    4630.0
# 25                            Tacna    1946    2513    2520    1921.0
# 26                           Tumbes    1535    1595    2267    2338.0
# 27                          Ucayali    2617    2272    3067    2235.0
#
#         2012      2013      2014      2015    2016    2017    2018    2019  \
# 0   271813.0  299474.0  326578.0  349323.0  355876  399869  466088  446508
# 1     4037.0    4806.0    3178.0    2395.0    3340    5696    6222    6039
# 2     7097.0    7618.0    8783.0    9862.0   10446   11798   13793   16980
# 3     2412.0    2993.0    2533.0    1601.0    2000    2566    4549    3821
# 4    13556.0   14167.0   16576.0   18017.0   19666   25500   28112   24856
# 5     3625.0    3989.0    4786.0    4395.0    3131    4574    6220    5572
# 6     5223.0    6820.0    6100.0    5847.0    6440    9453   10856   10196
# 7    13233.0   14631.0   15765.0   19328.0   15385   14948   22048   19297
# 8     8542.0    9830.0   14328.0    9271.0   11783   13728   15819   15771
# 9      962.0    1045.0    1917.0    1223.0    1345    1483    1582    1227
# 10    2601.0    3157.0    3275.0    3126.0    3162    3895    6191    6739
# 11    7835.0    9288.0   10107.0   10869.0   13178   13772   16374   18493
# 12    8337.0    9433.0    8791.0    7632.0    9375   11627   15018   16884
# 13   13413.0   13504.0   18712.0   15628.0   16782   21894   24283   25280
# 14   11356.0   12260.0   13740.0   15757.0   21406   25186   27315   26218
# 15       NaN       NaN       NaN       NaN  170295  177517  194005  174072
# 16  126309.0  136134.0  141269.0  169652.0  158167  163818  179510  160259
# 17    9468.0   10985.0    9987.0   10757.0   12128   13699   14495   13813
# 18    2825.0    3240.0    3054.0    2670.0    5730    4843    7655    7569
# 19    1549.0    2256.0    2118.0    1427.0    1641    2401    3381    2938
# 20    1568.0    1791.0    1804.0    1713.0    1872    2244    2905    2605
# 21    1183.0    1314.0    1987.0    1054.0     937    1772    2528    2260
# 22   11511.0   12178.0   16200.0   16099.0   16866   20156   23768   24714
# 23    2099.0    2445.0    4114.0    3314.0    4741    4206    5267    6385
# 24    4730.0    4665.0    5597.0    5545.0    3729    5177    8758    7764
# 25    3391.0    3850.0    3892.0    2975.0    3229    4013    4980    5229
# 26    2935.0    3437.0    3883.0    3163.0    3275    4404    5933    5240
# 27    2016.0    3638.0    4082.0    6003.0    6122    7016    8526   10359
#
#       2020    2021
# 0   320819  403071
# 1     4651    5242
# 2    11538   14634
# 3     3848    4618
# 4    19588   25087
# 5     5028    6372
# 6     9596   11900
# 7    12670   14648
# 8    12333   14801
# 9     1438    2363
# 10    6471    9011
# 11   13450   15640
# 12   12805   18071
# 13   18581   21854
# 14   18293   24619
# 15  113633  142877
# 16  101801  129960
# 17   11832   12917
# 18    5062    6799
# 19    2412    2908
# 20    1758    3034
# 21    2359    2425
# 22   18465   21886
# 23    5594    7091
# 24    6523    8922
# 25    3810    5331
# 26    4080    4956
# 27    6833    7982

# %%
# Connecting with spatial data (shapefile)
shp_file = 'DEPARTAMENTO.shp'
gdf = gpd.read_file(shp_file)

# %%
# Visualize spatial data
gdf.columns
# Out:
# Index(['DEPARTAMEN', 'SHAPE_Leng', 'SHAPE_Area', 'geometry'], dtype='object')

# %%
# Visualize spatial data
gdf.plot()

# %%
# Removing accents in the field DEPARTAM using field Departamento, and converting to upper case
df['DEPARTAMEN'] = df['Departamento'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')\
                         .str.upper()

# Changing some values in fiel DEPARTAM manually
df['DEPARTAMEN']  = df['DEPARTAMEN'].replace(['PROV. CONST. DEL CALLAO','LIMA METROPOLITANA 1/','LIMA 2/'],\
                                             ['CALLAO','LIMA METROPOLITANA','LIMA'])

# %%
df
# Out:
#                        Departamento    2008    2009    2010      2011  \
# 0                             Total  151560  160848  181866  240438.0
# 1                          Amazonas    1247     860     640    3309.0
# 2                            Áncash    5381    5744    6626    6325.0
# 3                          Apurímac    1191    1267    1389    1855.0
# 4                          Arequipa   10469   11110   10935   12762.0
# 5                          Ayacucho    2221    2124    1856    3299.0
# 6                         Cajamarca    3137    2665    3851    3775.0
# 7           Prov. Const. del Callao    8219    8935   10010   12749.0
# 8                             Cusco    4767    5742    6445    7145.0
# 9                      Huancavelica     110     273     600     879.0
# 26    2935.0    3437.0    3883.0    3163.0    3275    4404    5933    5240
# 27    2016.0    3638.0    4082.0    6003.0    6122    7016    8526   10359
#
#       2020    2021                       DEPARTAMEN
# 0   320819  403071                            TOTAL
# 1     4651    5242                         AMAZONAS
# 2    11538   14634                           ANCASH
# 3     3848    4618                         APURIMAC
# 4    19588   25087                         AREQUIPA
# 5     5028    6372                         AYACUCHO
# 6     9596   11900                        CAJAMARCA
# 7    12670   14648                           CALLAO
# 8    12333   14801                            CUSCO
# 9     1438    2363                     HUANCAVELICA
# 10    6471    9011                          HUANUCO
# 11   13450   15640                              ICA
# 12   12805   18071                            JUNIN
# 13   18581   21854                      LA LIBERTAD
# 14   18293   24619                       LAMBAYEQUE
# 15  113633  142877  LIMA METROPOLITANA 1/ Y LIMA 2/
# 16  101801  129960               LIMA METROPOLITANA
# 17   11832   12917                             LIMA
# 18    5062    6799                           LORETO
# 19    2412    2908                    MADRE DE DIOS
# 20    1758    3034                         MOQUEGUA
# 21    2359    2425                            PASCO
# 22   18465   21886                            PIURA
# 23    5594    7091                             PUNO
# 24    6523    8922                       SAN MARTIN
# 25    3810    5331                            TACNA
# 26    4080    4956                           TUMBES
# 27    6833    7982                          UCAYALI

# %%
# Joining spatial and tabular data by a field in commom
result = pd.merge(gdf, df, how="inner", on=["DEPARTAMEN"])

# %%
# Crear un blucle que elabore multiples mapas con anotaciones de actividad economica

# Path to saving maps
output_path = r'\MAPAS'

# Contador del blucle
i = 0

# Lista de actividades económicas
lista_etiqueta = df.columns.tolist()[4:-1]

# Colocar el valor máximo y mínimo para personal ocupado en el mapa de corropleta
vmin, vmax = result[lista_etiqueta].min().min(), result[lista_etiqueta].max().max()

# Empieza el bucle que crea mapa por actividad
for e in lista_etiqueta:
    
    # Crear el mapa
    fig = result.plot(column = e, cmap='Reds', figsize=(16,8), linewidth=0, edgecolor='0.8', vmin=vmin, vmax=vmax, 
                       legend=True, norm=plt.Normalize(vmin=vmin, vmax=vmax)) # UDPATE: added plt.Normalize to keep the legend range the same for all maps)

    # Elimina los ejes
    fig.axis('off')
    
    # Añade un título
    fig.set_title('Denuncias por comisión de delitos', \
              fontdict={'fontsize': '10',
                         'fontweight' : '3'})

    # Colocando la anotación de actividad en la parte inferior izquierda
    fig.annotate(str(e),
            xy=(0.1, .225), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            fontsize=10)
    
    # this will save the figure as a high-res png in the output path. you can also save as svg if you prefer.
    filepath = os.path.join('Denuncias'+str(e)+'.png')
    chart = fig.get_figure()
    chart.savefig(filepath, dpi=300)

# %%
import os
os.chdir(output_path)

# %%
import imageio

# %%
files = [f for f in os.listdir('.') if os.path.isfile(f)]
images = []
for f in files:
    images.append(imageio.imread(f))
imageio.mimsave('movie.gif', images, duration = '1', fps = 60)
